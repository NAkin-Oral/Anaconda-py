# %%
my_money = 1000  # ana para
f = 0.07  # faiz oranı
d = 7  # gün sayısı
end_money = my_money*(1+f)**d
print ("7 günün sonunda paranız",end_money)
# Out:
# 7 günün sonunda paranız 1605.7814764784307
