# %%
my_money = 1000  # ana para
f = 0.07  # faiz oranı
d = 7  # gün sayısı
end_money = my_money*(1+f)**d
print ("7 günün sonunda paranız")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6c781bf7dccd> in <module>()
#       3 d = 7  # gün sayısı
#       4 end_money = my_money*(1+f)**d
# ----> 5 print ("7 günün sonunda paranız")
#
# TypeError: 'tuple' object is not callable
