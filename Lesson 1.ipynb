# %%
print ("hello world")
# Out:
# hello world

# %%
print(" çift ile başlayıp bitti")
# Out:
#  çift ile başlayıp bitti

# %%
print("""hello 
my dear friends""")
# Out:
# hello
# my dear friends

# %%
print(41+95)
# Out:
# 136

# %%
print(''''alalal"''')
# Out:
# 'alalal"

# %%
prin()
print('''')
# Out:
#   File "<ipython-input-8-b3d3e8b7e8c2>", line 2
#     print('''')
#                ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
x=1
y=2
c=3
print("x,y,c")
# Out:
# x,y,c

# %%
x = 1
y = 2
c = 3
print(x,y,c)
# Out:
# 1 2 3

# %%
a = 36.5
b = '30'
c = '3.5'
d = ' F is enough for room temperature.'

print(str(a+int(b)+float(c))+d)
# Out:
# 70.0 F is enough for room temperature.

# %%
print(int("5" + "1"))
print(str("5" + "1"))
print("5" + "1")
# Out:
# 51
# 51
# 51

# %%
number_int = 123
number_flt = 1.23

number_new = number_flt + number_int

print("datatype of number_int: ", type(number_int))
print("datatype of number_flt: ", type(number_flt))

print("Value of the number_new:", number_new)
print("datatype of number_new: ", type(number_new))
# Out:
# datatype of number_int:  <class 'int'>
# datatype of number_flt:  <class 'float'>
# Value of the number_new: 124.23
# datatype of number_new:  <class 'float'>

# %%
number_int = 123
number_str = "456"

print("Data type of number_int: ", type(number_int))
print("Data type of number_str: ", type(number_str))

print(number_int+number_str)
# Out:
# Data type of number_int:  <class 'int'>
# Data type of number_str:  <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-795f33bf0a43> in <module>()
#       5 print("Data type of number_str: ", type(number_str))
#       6
# ----> 7 print(number_int+number_str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
X = "122"
y= 12
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c9ee7dbcbd31> in <module>()
#       1 X = "122"
#       2 y= 12
# ----> 3 print(x+y)
#
# NameError: name 'x' is not defined

# %%
number_int = 123
number_str = "456"

print("Data type of number_int: ", type(number_int))
print("Data type of number_str before Type Casting: ", type(number_str))

number_str = int(number_str)
print("Data type of number_str after Type Casting: ", type(number_str))

number_sum = number_int + number_str
print("Sum of number_int and number_str:", number_sum)
print("Data type of the sum:", type(number_sum))
# Out:
# Data type of number_int:  <class 'int'>
# Data type of number_str before Type Casting:  <class 'str'>
# Data type of number_str after Type Casting:  <class 'int'>
# Sum of number_int and number_str: 579
# Data type of the sum: <class 'int'>

# %%
name = input ("What is your name")
print ("hello", name)
age = int(input("How old are you"))
if age>=70:
  print("You are aged to perfection")
else:
  print("You are a spring chicken")
# Out:
# What is your nameAkın
# hello Akın
# How old are you24
# You are a spring chicken

# %%
print('www', 'clarusway', "com", sep='.', end=' ')
print('will', end=' ')
print('open', end=' ')
print('your', end=' ')
print('path', end='.')
# Out:
# www.clarusway.com will open your path.

# %%
print("clarusway" + 2020)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f0a156faa430> in <module>()
# ----> 1 print(str("clarusway" + 2020))
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(type("%d"))
# Out:
# <class 'str'>

# %%
print(1988+int("32"))
# Out:
# 2020

# %%
x = 12
y = x + 21
x = 2
print(y//x)
# Out:
# 16

# %%
x = False
y = not x
print(not (x and y))
# Out:
# True

# %%
print("{3} {2} {4} {1} {0} ".format('job.', 'a', 'will', 'I', 'find'))
# Out:
# I will find a job.

# %%
print(float("140" * int(input("Enter a number:" ))))
# Out:
# Enter a number:2
# 140140.0

# %%
var1 = "sleep"
var2 = "eat"
var3 = "better"
var4 = "life"
sentence = f"The less you {var1} and {var2}, the {var3} your {var4} will be"
print(sentence)
# Out:
# The less you sleep and eat, the better your life will be

# %%
city = "SARAJEVO"
text = f"I live in {str.capitalize(city)}"
print(text)
# Out:
# I live in Sarajevo

# %%
city = "SARAJEVO"
text = f"{city.capitalize()}"
print(f"I live in {text}")
# Out:
# I live in Sarajevo

# %%
name = "Susan"
age = "young"
gender = "lady"
school = "CLRWY IT university"
message =(
    f" {name} is a {age}"
    f" {gender} and she is a student"
    f" at the {school}"
)
print (message)
# Out:
#  Susan is a young lady and she is a student at the CLRWY IT university

# %%
text = "www.clarusway.com"
print(text.endswith(".com"))
print(text.startswith("http:"))
# Out:
# True
# False

# %%
sentence = "I live and work in Virginia"
print(sentence.upper())
print(sentence.lower())
print(sentence.swapcase())
print(sentence)
# Out:
# I LIVE AND WORK IN VIRGINIA
# i live and work in virginia
# i LIVE AND WORK IN vIRGINIA
# I live and work in Virginia

# %%
text = "tyou can learn almost eveything in pre-classz"
print(text.strip("tz").upper())
# Out:
# YOU CAN LEARN ALMOST EVEYTHING IN PRE-CLASS

# %%
word = 'clarusway'
n = 3
front = word[0:3]
back = word [4:]
print(front + back)
# Out:
# clausway

# %%
text = "{0}! I am a {1} programmer and I {2} Clasrusway. ".format("Hello", "new", "love")
print(text)
# Out:
# Hello! I am a new programmer and I love Clasrusway.

# %%
print (1 + 4*3)
# Out:
# 13

# %%
print(5! = 6)
# Out:
#   File "<ipython-input-3-a01770bcc4f1>", line 1
#     print(5! = 6)
#            ^
# SyntaxError: invalid syntax

# %%
Celsius = float(input("Enter a temperature in Celsius:"))
Fahrenheit = 1.8 * Celsius + 32
print("Temperature: ", Fahrenheit, "F")
# Out:
# Enter a temperature in Celsius:19.2
# Temperature:  66.56 F

# %%
Kilometer = float(input("Enter a distance in Kilometer:"))
Mile = Kilometer / 0.1609
print("Distance", Mile, "miles")
# Out:
# Enter a distance in Kilometer:150
# Distance 932.2560596643879 miles

# %%
age = float(input("Your age:"))
addiction = (input("Do you smoke: (If yes type yes or just press enter) "))
im = (input("""
Is your immune system weak: (If yes type yes or just press enter) """))
chr = (input("""
Do you have a chronic disease? (If yes type yes or just press enter) """))
age = (age // 75)
possibility = bool(age) and bool(addiction) or bool(im) or bool(chr)
print("If you are in 'True' value than you are in danger.")
print("*****   ", possibility, "   *****")
# Out:
# Your age:75
# Do you smoke: (If yes type yes or just press enter)
#
# Is your immune system weak: (If yes type yes or just press enter)
#
# Do you have a chronic disease? (If yes type yes or just press enter)
# If you are in 'True' value than you are in danger.
# *****    False    *****

# %% [markdown]
# The process of working collaboratively with a group of people in order to achieve a goal. Teamwork is often a crucial part of a business, as it is often necessary for colleagues to work well together, trying their best in any circumstance. Teamwork means that people will try to cooperate, using their individual skills and providing constructive feedback, despite any personal conflict between individuals.
# the combined action of a group, especially when effective and efficient.

# %% [markdown]
# The process of working collaboratively,specially when effective and efficient, with a group of people in order to achieve a goal. Teamwork means that people will try to cooperate, using their individual skills and providing constructive feedback, despite any personal conflict between individuals.

# %%
year = int(input("Enter the year you cant see if it is a leap year: "))
var_1 = (year % 4)
var_2 = (year % 100)
var_3 = (year % 400)
print (bool(var_1 and var_2 and var_3))
# Out:
# Enter the year you cant see if it is a leap year: 2000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-16a38008be7f> in <module>()
#       3 var_2 = (year % 100)
#       4 var_3 = (year % 400)
# ----> 5 print (bool(var_1 and var_2 and var_3))
#       6
#
# TypeError: 'bool' object is not callable

# %%
my-var = 5
my-var
# Out:
#   File "<ipython-input-1-60b191c0b58e>", line 1
#     my-var = 5
#               ^
# SyntaxError: can't assign to operator

# %%
example = "snow world"
print("%s" % example[4:7])
# Out:
#  wo

# %%
print("abcd"[2:])
# Out:
# cd

# %%
print(chr(ord('b')+1))
# Out:
# c

# %%
print(format("Welcome", "10s"), end = '#')
print(format(111, "4d"), end = '#')
print(format(924.656, "3.2f"))
# Out:
# Welcome   # 111#924.66

# %%
print("xyyzxyzxzxyy".count('yy', 2))
# Out:
# 1

# %%
print("xyyzxyzxzxyy".endswith("xyy", 0, 2))
# Out:
# False

# %%
print("xyyzxyzxzxyy".count('xyy', 2, 11))
# Out:
# 0

# %%
print('abcdefcdghcd'.split('cd'))
# Out:
# ['ab', 'ef', 'gh', '']

# %%
x = “Hello”
x.replace(“l”, “e”)
# Out:
#   File "<ipython-input-5-65488bff0c8a>", line 1
#     x = “Hello”
#               ^
# SyntaxError: invalid character in identifier

# %%
x = 1
if x < 10000:
  for i in range(0,):
    print(x)
    x += i

# %%
def  my_function (a, b) :
    return (a * b)
print(my_function(3, 4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fb1ee0a20e58> in <module>()
#       1 def  my_function (a, b) :
#       2     return (a * b)
# ----> 3 print(my_function(3, 4))
#
# TypeError: 'int' object is not callable

# %%
def make_sentence(**kwargs):
    result = ""
    # Iterating over the Python kwargs dictionary
    for i in kwargs.values():
        result += i
    return result

print(make_sentence(a="I ", b="love ", c="Clarusway!"))
# Out:
# I love Clarusway!

# %%
def team_league(team, league='Premier League'):
    print(team, 'in', league)

team_league('Liverpool')
# Out:
# Liverpool in Premier League

# %%
def my_function(first, last) : 
    print('Your first name is :', first)
    print('Your last name is :', last)

my_function(first='Richard', last='Rice')
# Out:
# Your first name is : Richard
# Your last name is : Rice

# %%
sentence = input("Enter the sentence you want to delete the vowels: ")
sentence = sentence.lower()
def vovels(letter):
    vovels = "a, e, ı, i, o, ö, u, ü".split()
    if letter.lower() in vovels:
        return True
    else:
        return False
filtered_vovels = filter(vovels, sentence)
print(list(filtered_vovels))
# Out:
# Enter the sentence you want to delete the vowels: Halleluya
# []

# %%
for i in range(1,101):
  if (i % 3 == 0) and (i %5 == 0):
    print("FizzBuzz")
  elif i % 3 == 0:
    print("Fizz")
  elif i % 5 == 0:
    print("Buzz")
  else:
    print(i)
# Out:
# FizzBuzz
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
x = input("Ebter a sentence: ")
letters = set(x)
print(letters)
for i in letters:
  y=letters.count(i)
  print(y)
# Out:
# Ebter a sentence: hippo runs to us!
# {'p', '!', 't', 'u', ' ', 's', 'h', 'n', 'i', 'r', 'o'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1ef9c624f951> in <module>()
#       3 print(letters)
#       4 for i in letters:
# ----> 5   y=letters.count(i)
#       6   print(y)
#
# AttributeError: 'set' object has no attribute 'count'

# %%
from collections import Counter
x = input("Ebter a sentence: ")
letters = set(x)
print(Counter(letters))
# Out:
# Ebter a sentence: hippo runs to us!
# Counter({'p': 1, '!': 1, 't': 1, 'u': 1, ' ': 1, 's': 1, 'h': 1, 'n': 1, 'i': 1, 'r': 1, 'o': 1})
